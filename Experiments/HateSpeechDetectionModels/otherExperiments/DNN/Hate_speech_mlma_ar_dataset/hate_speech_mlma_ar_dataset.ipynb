# %%
import keras 
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_excel('/content/drive/My Drive/Master thesis/DataSet-forUsing/4-hate_speech_mlma_ar_dataset.xlsx',usecols=['tweet', 'sentiment'])

data["HS_NOT"] = data.apply(lambda x: "Not-HS" if x["sentiment"] in ['normal'] else "HS",axis =1)
data.head()
# Out:
#                                                tweet       sentiment  HS_NOT
# 0  صلاة الفجر خير لك من ترديد بول البعير وسبي الن...  hateful_normal      HS
# 1  صراحة نفسي اشوف ولاد الوسخة اللي قالوا مدرب اج...       offensive      HS
# 2  طيب! هي متبرجة وعبايتها ملونه وطالعة من بيتهم ...       offensive      HS
# 3  @user @user انا اوافقك بخصوص السوريين و العراق...          normal  Not-HS
# 4  هذه السعودية التي شعبها شعب الخيم و بول البعير...          normal  Not-HS

# %%
Y=data.HS_NOT
Y
# Out:
# 0           HS
# 1           HS
# 2           HS
# 3       Not-HS
# 4       Not-HS
#          ...
# 3348        HS
# 3349        HS
# 3350        HS
# 3351        HS
# 3352    Not-HS
# Name: HS_NOT, Length: 3353, dtype: object

# %%
X=data.drop('HS_NOT',axis=1)
X
# Out:
#                                                   tweet             sentiment
# 0     صلاة الفجر خير لك من ترديد بول البعير وسبي الن...        hateful_normal
# 1     صراحة نفسي اشوف ولاد الوسخة اللي قالوا مدرب اج...             offensive
# 2     طيب! هي متبرجة وعبايتها ملونه وطالعة من بيتهم ...             offensive
# 3     @user @user انا اوافقك بخصوص السوريين و العراق...                normal
# 4     هذه السعودية التي شعبها شعب الخيم و بول البعير...                normal
# ...                                                 ...                   ...
# 3348  @user يمشي بخطا ادارتها قيد من الأمريكان ونهب ...  disrespectful_normal
# 3349  @user مهما حصل هندوس عليهم شويه الرويبضه بس نخ...               hateful
# 3350           الكلب لا يعض اذن اخوه كذابين خنازير @url     offensive_hateful
# 3351  @user لأنه صغير ويكتب في قناة خنازير فلن نقرأ ...               hateful
# 3352      الحريم أجمع افلوس وايفون قديم وواتساب ?? ساعة                normal
#
# [3353 rows x 2 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2)
x_train.head()
# Out:
#                                                   tweet              sentiment
# 1357  @user @user @user @user @user @user بغدادي وسخ...  abusive_disrespectful
# 1802  يوجد أربع عراقيين بالصحراءواحد يقص قصةشاب مريض...  abusive_disrespectful
# 2058  وين الحريم إليّ مبثريني لما كنت بزر بخطبك لولد...                 normal
# 300          @user @user ابن خالتي انا #خنزير_ال_ام_كيه              offensive
# 549   مين تبي الحس كسها وينها اربعينيه ثلاثينية او م...              offensive

# %%
# word_index = data.get_word_index(path="reuters_word_index.json")

# %%
 from sklearn.preprocessing import LabelBinarizer
 encoder = LabelBinarizer()
 transfomed_label = encoder.fit_transform(["Not-HS", "HS"])
 print(transfomed_label)
# Out:
# [[1]
#  [0]]

# %%
print('# of Training Samples: {}'.format(len(x_train)))
print('# of Test Samples: {}'.format(len(x_test)))

num_classes = max(transfomed_label) + 1
print('# of Classes: {}'.format(num_classes))
print(x_train[1])
# Out:
# # of Training Samples: 2
# # of Test Samples: 2
# # of Classes: [2]
# []

# %%
index_to_word = {}
for key, value in word_index.items():
    index_to_word[value] = key
print(' '.join([index_to_word[x] for x in x_train[0]]))
print(y_train[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-1192b3072a6e> in <module>()
#       1 index_to_word = {}
# ----> 2 for key, value in word_index.items():
#       3     index_to_word[value] = key
#       4 print(' '.join([index_to_word[x] for x in x_train[0]]))
#       5 print(y_train[0])
#
# NameError: name 'word_index' is not defined

# %%
from keras.preprocessing.text import Tokenizer

max_words = 10000

tokenizer = Tokenizer(num_words=max_words)
x_train = tokenizer.texts_to_sequences(x_train)
x_test = tokenizer.texts_to_sequences(x_test)

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
print(x_train[0])
print(len(x_train[0]))

print(y_train[0])
print(len(y_train[0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-2e1a46995d60> in <module>()
#       7 x_test = tokenizer.texts_to_sequences(x_test)
#       8
# ----> 9 y_train = keras.utils.to_categorical(y_train, num_classes)
#      10 y_test = keras.utils.to_categorical(y_test, num_classes)
#      11 print(x_train[0])
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/np_utils.py in to_categorical(y, num_classes, dtype)
#      67
#      68   """
# ---> 69   y = np.array(y, dtype='int')
#      70   input_shape = y.shape
#      71   if input_shape and input_shape[-1] == 1 and len(input_shape) > 1:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in __array__(self, dtype)
#     795               dtype='datetime64[ns]')
#     796         """
# --> 797         return np.asarray(self.array, dtype)
#     798
#     799     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/arrays/numpy_.py in __array__(self, dtype)
#     209
#     210     def __array__(self, dtype=None) -> np.ndarray:
# --> 211         return np.asarray(self._ndarray, dtype=dtype)
#     212
#     213     _HANDLED_TYPES = (np.ndarray, numbers.Number)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: invalid literal for int() with base 10: 'HS'

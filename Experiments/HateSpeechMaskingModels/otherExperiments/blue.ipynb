# %%
# !pip install git+https://github.com/Maluuba/nlg-eval.git@master
# !pip install git 
! git clone https://github.com/Maluuba/nlg-eval.git
# Out:
# Cloning into 'nlg-eval'...
# remote: Enumerating objects: 377, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 377 (delta 16), reused 10 (delta 4), pack-reused 337
# Receiving objects: 100% (377/377), 65.12 MiB | 32.49 MiB/s, done.
# Resolving deltas: 100% (179/179), done.

# %%
# !nlg-eval --setup
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Installing to /root/.cache/nlgeval
# In case of incomplete downloads, delete the directory and run `nlg-eval --setup /root/.cache/nlgeval' again.
# ...
# glove2word2vec.py: 100% 1.00/1.00 [00:00<00:00, 494 chunks/s]

# %%
# !pip install pytest
# !pytest
# Out:
# ...
# ============================= test session starts ==============================
# platform linux2 -- Python 2.7.17, pytest-3.6.4, py-1.8.0, pluggy-0.7.1
# rootdir: /content, inifile:
# collected 5 items / 2 errors
#
# ==================================== ERRORS ====================================
# _ ERROR collecting drive/MyDrive/MasterThesis/paraphrasing/outputs - Copy/bleu/tests/test_metrics.py _
# drive/MyDrive/MasterThesis/paraphrasing/outputs - Copy/bleu/tests/test_metrics.py:8: in <module>
#     class TestMetrics(unittest.TestCase):
# drive/MyDrive/MasterThesis/paraphrasing/outputs - Copy/bleu/tests/test_metrics.py:9: in TestMetrics
#     reference_corpus = load_reference_corpus(REF_FILES)
# drive/MyDrive/MasterThesis/paraphrasing/outputs - Copy/bleu/utils.py:10: in load_reference_corpus
#     with open(file) as f:
# E   TypeError: coercing to Unicode: need string or buffer, PosixPath found
# _ ERROR collecting nlg-eval/nlgeval/pycocoevalcap/meteor/tests/test_meteor.py __
# ...

# %%
from nlgeval import compute_metrics
metrics_dict = compute_metrics(hypothesis='/content/nlg-eval/examples/hyp.txt',
                               references=['/content/nlg-eval/examples/ref1.txt', '/content/nlg-eval/examples/ref2.txt'])

# %%
# metrics_dict = compute_metrics(hypothesis='/content/nlg-eval/examples/hyp.txt',
                              #  references=['/content/nlg-eval/examples/ref1.txt', '/content/nlg-eval/examples/ref2.txt'])

# %%
# act = pathlib.Path('/content/drive/MyDrive/MasterThesis/paraphrasing/outputs/act2.txt')
# pred = pathlib.Path('/content/drive/MyDrive/MasterThesis/paraphrasing/outputs/pred3183_10000.txt')
from nlgeval import NLGEval
nlgeval = NLGEval()  # loads the models

with open('/content/drive/MyDrive/MasterThesis/paraphrasing/outputs/act2.txt','rU') as f1, open('/content/drive/MyDrive/MasterThesis/paraphrasing/outputs/pred3183_10000.txt','rU') as f2:
    for s[1],e[1] in zip(f1,f2):
      print(s[1])
        # print("{}{}".format(s.rstrip(),e.rstrip()))
        # metrics_dict = nlgeval.compute_individual_metrics(s, e)
        # print(metrics_dict)

# %%
from nltk.translate.bleu_score import SmoothingFunction


predicted_list = []
test_inp_texts = [pair[0] for pair in test_pairs]
test_targ_texts = [pair[1] for pair in test_pairs]


for i,j in zip(test_inp_texts,test_targ_texts):

  # input_sentence = test_inp_texts
  # translated = decode_sequence(i)
  # predicted = list(translated.split(","))
  metrics_dict = nlgeval.compute_individual_metrics(j, i)
  print(metrics_dict)
  # print("blue 1-gram : ",score_1,"\n","blue 2-gram : ",score_2,"\n","blue 3-gram : ",score_3,"\n","blue 4-gram : ",score_4,"\n")
